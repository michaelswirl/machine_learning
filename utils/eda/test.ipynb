# %%
from sklearn.datasets import make_regression, make_classification
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error, roc_auc_score, precision_score, f1_score, recall_score

# %%
df = pd.read_csv('/Users/michaelcurley/Downloads/CBBTrainingSet.csv')

df['Win'] = df['GameOutcome']=='Home Win'

df
# Out:
#        GameID  HomeTeamID  AwayTeamID  HomeFieldGoalsMade  \
# 0       30825          59         149           25.102941
# 1       32752          99         299           23.248120
# 2       32760         102         196           25.718519
# 3       32769         362         834           24.738095
# 4       32514          34         201           24.531250
# ...       ...         ...         ...                 ...
# 24847   56979          71         316           25.833333
# 24848   59451         248         247           29.166667
# 24849   59455         254         246           26.500000
# 24850   58559          85          86           30.666667
# 24851   57391         227         224           32.000000
#
#        HomeFieldGoalsAttempted  HomeTwoPointersMade  HomeTwoPointersAttempted  \
# 0                    54.455882            18.669118                 35.904412
# 1                    52.563910            16.172932                 31.451128
# ...

# %%
from BinaryClassificationFeatureExplorer import BinaryClassificationFeatureExplorer



explorer = BinaryClassificationFeatureExplorer(df, 'Win')


explorer.explore_numerical_variables()
# Out:
# ...
# Output()
